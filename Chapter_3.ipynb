# %% [markdown]
# <!-- 3.1 -->

# %%
60*60
# Out:
# 3600

# %% [markdown]
# seconds_per_hour = 60*60

# %%
seconds_per_hour*24
# Out:
# 86400

# %%
seconds_per_day = seconds_per_hour * 24

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Yes, both of the values are the same except for the .0 at the end.
