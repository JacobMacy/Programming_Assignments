# %%
secret = 7

# %%
guess = 3

# %%
if guess < secret:
    print('too low')
elif guess > secret:
    print('too high')
else:
    print('just right')
# Out:
# too low

# %%
small = False
green = True
if small:
    if green:
        print('It is a pea')
    else:
        print('It is a cherry')
else:
    if green:
        print('It is a watermelon')
    else:
        print('It is a pumpkin')
# Out:
# It is a watermelon

# %%
list = [3,2,1,0]
for value in list:
    print(value)
# Out:
# 3
# 2
# 1
# 0

# %%
guess_me = 7
number = 1
while True:
    if number < guess_me:
        print('too low')
    else:
        if number > guess_me:
            print('oops')
        else:
            print('found it!')
        break
    number+=1
# Out:
# too low
# too low
# too low
# too low
# too low
# too low
# found it!

# %%
guess_me = 5
for number in range(10):
    if number < guess_me:
        print('too low')
    else:
        if number > guess_me:
            print('oops')
        else:
            print('found it!')
        break
# Out:
# too low
# too low
# too low
# too low
# too low
# found it!
